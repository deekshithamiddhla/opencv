# %%
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("/content/Gray.jpeg")
img1 = cv2.resize(img, (500,300))
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>

# %%
import numpy as np

# %%
#img1 = cv2.imread('/content/Gray.jpeg', 0)

# %%
#cv2_imshow(img1)

# %%
kernel = np.ones((5, 5), np.uint8)

# %%
img_erosion = cv2.erode(img1, kernel, iterations=1)
img_dilation = cv2.dilate(img1, kernel, iterations=1)

cv2_imshow(img1)
cv2_imshow(img_erosion)
cv2_imshow(img_dilation)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>
# <PIL.Image.Image image mode=RGB size=500x300>
# <PIL.Image.Image image mode=RGB size=500x300>
# -1

# %%
img1 = cv2.imread('/content/brain.png', 0)
#cv2_imshow(img1)
kernel = np.ones((5, 5), np.uint8)
img_erosion = cv2.erode(img1, kernel, iterations=2)
img_dilation = cv2.dilate(img1, kernel, iterations=1)

cv2_imshow(img1)
cv2_imshow(img_erosion)
cv2_imshow(img_dilation)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=604x604>
# <PIL.Image.Image image mode=L size=604x604>
# <PIL.Image.Image image mode=L size=604x604>
# -1

# %%
img1 = cv2.imread('/content/colour.jpeg', 0)
#cv2_imshow(img1)
kernel = np.ones((5, 5), np.uint8)
img_erosion = cv2.erode(img1, kernel, iterations=2)
img_dilation = cv2.dilate(img1, kernel, iterations=1)

cv2_imshow(img1)
cv2_imshow(img_erosion)
cv2_imshow(img_dilation)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# -1

# %%
#histogram equalization
img1 = cv2.imread('/content/colour.jpeg', 1)
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img = cv2.imread('/content/colour.jpeg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img = cv2.imread('/content/brain.png',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img = cv2.imread('/content/Gray.jpeg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img = cv2.imread('/content/colour.jpeg',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ)) #stacking images side-by-side
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=550x183>

# %%
img2= cv2.imread('/content/Gray.jpeg')
#cv2_imshow(img2)
imgg=np.uint8(img2)
imgg= cv2.cvtColor(imgg, cv2.COLOR_BGR2GRAY)
imgn = cv2.resize(imgg,(500,300))
cv2_imshow(imgn)
#equ = cv2.equalizeHist(img1)
equ = cv2.equalizeHist(imgn)
#res = np.hstack((imgg,imgn)) #stacking images side-by-side
cv2_imshow(equ)
# Out:
# <PIL.Image.Image image mode=L size=500x300>
# <PIL.Image.Image image mode=L size=500x300>

# %%
img = cv2.imread("/content/brain.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
equ=cv2.equalizeHist(img)
img1 = cv2.resize(equ,(300,300))
img2 = cv2.resize(img, (300,300))
res = np.hstack((img1,img2))
cv2_imshow(res)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=600x300>
# -1

# %%
img=cv2.imread("/content/colour.jpeg")
r1= cv2.equalizeHist(img[:,:,0])
cv2_imshow(r1)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
b, g, r = cv2.split(img)

# Apply histogram equalization to each color channel
b_eq = cv2.equalizeHist(b)
g_eq = cv2.equalizeHist(g)
r_eq = cv2.equalizeHist(r)
cv2_imshow(b_eq)
cv2_imshow(g_eq)
cv2_imshow(r_eq)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>

# %%
img = cv2.imread('/content/colour.jpeg')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([50,100])
plt.show()

# %%
#colour conversions
#colour to gray
image = cv2.imread('/content/colour.jpeg')
cv2_imshow(image)
cv2.waitKey(0)

# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2_imshow( gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# -1

# %%
image = cv2.imread('/content/colour.jpeg',0)
cv2_imshow(image)
cv2.waitKey(0)

# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

cv2_imshow( gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=RGB size=275x183>
# -1

# %%
#binary thresholding
image = cv2.imread('/content/colour.jpeg')
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 120, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO_INV)
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow( thresh4)
cv2_imshow(thresh5)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>

# %%
#gray to binary
img = cv2.imread('/content/colour.jpeg')

# convert the input image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# apply thresholding to convert grayscale to binary image
ret,thresh = cv2.threshold(gray,70,255,0)

# Display the Binary Image
cv2_imshow( thresh)
cv2.waitKey(0)

# %%
#gray to binary
img = cv2.imread('/content/colour.jpeg',0)

# convert the input image to grayscale
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# apply thresholding to convert grayscale to binary image
ret,thresh = cv2.threshold(gray,70,255,0)

# Display the Binary Image
cv2_imshow( thresh)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# -1

# %%
#rgb to hsv
#hsv_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2HSV)
img = cv2.imread('/content/colour.jpeg')

# convert the input image to grayscale
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

cv2_imshow( hsv_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# -1

# %%
#canny edge detection
img = cv2.imread('/content/colour.jpeg',0)
edges = cv2.Canny(img,400,200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
